# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.metrics import R2Score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Гиперпараметры
input_shape = (1024, 1)  # Размер входных данных (длина последовательности)
output_shape = input_shape[0] // 2 + 1  # Размер выходных данных (половина длины последовательности + 1)
batch_size = 50
epochs = 15
learning_rate = 0.001
num_samples = 20000
tau = 1

# %%
# Генерация данных
def generate_data(tau, num_samples):
    signals = []
    labels = []
    for _ in range(num_samples):
        # Генерация случайного сигнала
        n_sin = np.random.choice(np.arange(0, 5))
        n_cos = np.random.choice(np.arange(0, 5))
        time = np.linspace(0.0, 1.0, num=input_shape[0]) * tau
        freq = np.random.uniform(0.1, 10.0, size=(n_sin+n_cos))  # Случайная частота
        amplitude = np.random.uniform(0.5, 100.0, size=(n_sin+n_cos))  # Случайная амплитуда
        noise = np.random.normal(0, 1, size=input_shape)  # Шум
        signal = noise
        for i in range(n_sin):
            signal += amplitude[i] * np.sin(2 * np.pi * freq[i] * time).reshape(input_shape)
        for i in range(n_sin, n_sin+n_cos):
            signal += amplitude[i] * np.cos(2 * np.pi * freq[i] * time).reshape(input_shape)
        signals.append(signal)

        # Вычисление спектральной плотности мощности
        spectrum = np.abs(np.fft.fft(signal))[:output_shape]
        spectrum_db = 20 * np.log10(spectrum / np.max(spectrum))  # Преобразование в дБ
        labels.append(spectrum_db)

    return np.array(signals), np.array(labels)

# %%
# Определение модели

def create_model(num_layers, filters, kernel_size):
    model = models.Sequential()
    for i in range(num_layers):
        model.add(layers.Conv1D(filters[i], kernel_size, activation='linear'))
        model.add(layers.BatchNormalization())
        model.add(layers.Activation('relu'))
        model.add(layers.MaxPooling1D(2))
    model.add(layers.Flatten())
    model.add(layers.Dense(1024, activation='relu'))
    model.add(layers.Dense(output_shape))  # Выходной слой
    return model

# %%
print("Num GPUs Available:", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
x, y = generate_data(1, num_samples)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
y_train.shape
# Out:
# (16000, 513, 1)

# %%
# Создание и компиляция модели
model = create_model(num_layers=4, filters=[3, 9, 18, 32], kernel_size=5)
optimizer = optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='mae')

# Обучение модели
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Оценка модели
loss = model.evaluate(x_test, y_test)
print("Test Loss:", loss)
# допилить метрику качества (в логариф.)
# Out:
# Epoch 1/15
# 320/320 [==============================] - 6s 9ms/step - loss: 3.8775 - val_loss: 4.0808
# Epoch 2/15
# 320/320 [==============================] - 3s 10ms/step - loss: 2.5360 - val_loss: 2.2644
# Epoch 3/15
# 320/320 [==============================] - 2s 7ms/step - loss: 2.2562 - val_loss: 2.0645
# Epoch 4/15
# 320/320 [==============================] - 2s 7ms/step - loss: 2.1286 - val_loss: 1.9370
# Epoch 5/15
# 320/320 [==============================] - 2s 7ms/step - loss: 2.0303 - val_loss: 1.9479
# Epoch 6/15
# 320/320 [==============================] - 2s 7ms/step - loss: 1.9894 - val_loss: 1.8045
# Epoch 7/15
# 320/320 [==============================] - 3s 10ms/step - loss: 1.9390 - val_loss: 1.7706
# Epoch 8/15
# 320/320 [==============================] - 2s 8ms/step - loss: 1.8877 - val_loss: 1.7378
# Epoch 9/15
# 320/320 [==============================] - 2s 7ms/step - loss: 1.8247 - val_loss: 1.6882
# Epoch 10/15
# 320/320 [==============================] - 2s 7ms/step - loss: 1.8026 - val_loss: 1.6986
# Epoch 11/15
# 320/320 [==============================] - 2s 8ms/step - loss: 1.7438 - val_loss: 1.6531
# Epoch 12/15
# 320/320 [==============================] - 3s 9ms/step - loss: 1.7305 - val_loss: 1.6705
# Epoch 13/15
# 320/320 [==============================] - 3s 9ms/step - loss: 1.7101 - val_loss: 1.5974
# Epoch 14/15
# 320/320 [==============================] - 2s 7ms/step - loss: 1.7131 - val_loss: 1.6204
# Epoch 15/15
# 320/320 [==============================] - 2s 7ms/step - loss: 1.6582 - val_loss: 1.6165
# 125/125 [==============================] - 1s 3ms/step - loss: 1.6165
# Test Loss: 1.6165447235107422

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_32 (Conv1D)          (None, 1020, 3)           18
#
#  batch_normalization_32 (Ba  (None, 1020, 3)           12
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 1020, 3)           0
#
#  max_pooling1d_32 (MaxPooli  (None, 510, 3)            0
#  ng1D)
#
#  conv1d_33 (Conv1D)          (None, 506, 9)            144
#
#  batch_normalization_33 (Ba  (None, 506, 9)            36
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 506, 9)            0
#
#  max_pooling1d_33 (MaxPooli  (None, 253, 9)            0
#  ng1D)
#
#  conv1d_34 (Conv1D)          (None, 249, 18)           828
#
#  batch_normalization_34 (Ba  (None, 249, 18)           72
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 249, 18)           0
#
#  max_pooling1d_34 (MaxPooli  (None, 124, 18)           0
#  ng1D)
#
#  conv1d_35 (Conv1D)          (None, 120, 32)           2912
#
#  batch_normalization_35 (Ba  (None, 120, 32)           128
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 120, 32)           0
#
#  max_pooling1d_35 (MaxPooli  (None, 60, 32)            0
#  ng1D)
#
#  flatten_8 (Flatten)         (None, 1920)              0
#
#  dense_16 (Dense)            (None, 1024)              1967104
#
#  dense_17 (Dense)            (None, 513)               525825
#
# =================================================================
# Total params: 2497079 (9.53 MB)
# Trainable params: 2496955 (9.53 MB)
# Non-trainable params: 124 (496.00 Byte)
# _________________________________________________________________

# %%
fig, ax = plt.subplots(3, 3, figsize=(12, 12))
ax = ax.ravel()
for i in range(9):
    ax[i].plot(y_test[i], 'r', label='Target')
    ax[i].plot(np.array(model(np.array([x_test[i]]))).reshape(-1), 'b', label='Predicted')
    ax[i].legend()
plt.show()

# %%
plt.plot(10**(y_test[9]/20), 'r', label='Target')
plt.plot(10**(np.array(model(np.array([x_test[9]]))).reshape(-1)/20), 'b--', label='Predicted')
plt.legend()
plt.show()

# %%
y_test.shape, np.array(model(np.array(x_test))).shape
# Out:
# ((2000, 513, 1), (2000, 513))

# %% [markdown]
# Выберем метрику R2 (коэф. детерминации) для оценки регрессии, то есть мы будем определять долю объясненной дисперсии  моделью.

# %%
metric_dB = R2Score()
metric_dB.update_state(np.squeeze(y_test, axis=2), np.array(model(np.array(x_test))))
result_dB = metric_dB.result()

# %%
result_dB
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.84081477>

# %%
metric = R2Score()
metric.update_state(10**(np.squeeze(y_test, axis=2)/20), 10**(np.array(model(np.array(x_test)))/20))
result = metric.result()

# %%
result
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.93487036>

# %%
from tensorflow.keras.models import load_model

# %%
from IPython.display import clear_output
import time

# %%
for _ in range(10):
  clear_output()
  x_t, y_t = generate_data(1, 1)
  plt.plot(y_t[0], 'r', label='Target')
  plt.plot(np.array(model(np.array(x_t))).reshape(-1), 'b', label='Predicted')
  plt.legend()
  plt.show()
  time.sleep(1)
